# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'c:\\Users\\brend\\VSCode Projects\\school_personal\\stat386\\FinalProject\\Stat386-FinalProject-Divorce-Crime\\src\\stat386_finalproject_divorce_crime\\notebooks'

# %%
df = pd.read_csv("../../data/Combined_DF.csv")

# %%
cols_to_drop = ['Unnamed: 0.1', 'index', 'Unnamed: 0', 'state.1']
df = df.drop(columns=cols_to_drop)

# %%
df.columns
# Out:
# Index(['state', 'year', 'V_actual', 'V_clearance_actual', 'ASS_actual',
#        'ASS_clearance_actual', 'BUR_actual', 'BUR_clearance_actual',
#        'LAR_actual', 'LAR_clearance_actual', 'MVT_actual',
#        'MVT_clearance_actual', 'HOM_actual', 'HOM_clearance_actual',
#        'RPE_actual', 'RPE_clearance_actual', 'ROB_actual',
#        'ROB_clearance_actual', 'ARS_actual', 'ARS_clearance_actual',
#        'P_actual', 'P_clearance_actual', 'V_rate', 'V_clearance_rate',
#        'population', 'participated_population', 'ASS_rate',
#        'ASS_clearance_rate', 'BUR_rate', 'BUR_clearance_rate', 'LAR_rate',
#        'LAR_clearance_rate', 'MVT_rate', 'MVT_clearance_rate', 'HOM_rate',
#        'HOM_clearance_rate', 'RPE_rate', 'RPE_clearance_rate', 'ROB_rate',
#        'ROB_clearance_rate', 'ARS_rate', 'ARS_clearance_rate', 'P_rate',
#        'P_clearance_rate', 'population_over_15', 'married_males_last_year',
#        'married_females_last_year', 'divorced_males_last_year',
# ...

# %%
df.head()
# Out:
#      state  year  V_actual  V_clearance_actual  ASS_actual  \
# 0  Alabama  2011   19666.0              7716.0     13204.0
# 1  Alabama  2012   21148.0              7262.0     14612.0
# 2  Alabama  2013   19725.0              8953.0     13041.0
# 3  Alabama  2014   19603.0              8945.0     12970.0
# 4  Alabama  2015   22117.0              8915.0     15315.0
#
#    ASS_clearance_actual  BUR_actual  BUR_clearance_actual  LAR_actual  \
# 0                5611.0     49629.0                6368.0    108787.0
# 1                5488.0     46176.0                5399.0    108195.0
# 2                6263.0     39860.0                5853.0    103176.0
# 3                6209.0     37397.0                5496.0     98385.0
# 4                6331.0     33854.0                4886.0     95735.0
#
#    LAR_clearance_actual  ...  ARS_clearance_rate      P_rate  \
# 0               23068.0  ...            0.295000  302.635000
# 1               22184.0  ...            0.307500  295.379167
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.1        index         year       V_actual  \
# count     650.00000   650.000000   650.000000     650.000000
# mean      324.50000  1036.807692  2017.307692   23720.430769
# std       187.78312   592.135673     4.124126   30262.808852
# min         0.00000    26.000000  2011.000000     636.000000
# 25%       162.25000   524.250000  2014.000000    4828.000000
# 50%       324.50000  1037.000000  2017.000000   16310.000000
# 75%       486.75000  1548.750000  2021.000000   28312.250000
# max       649.00000  2048.000000  2024.000000  201266.000000
#
#        V_clearance_actual     ASS_actual  ASS_clearance_actual     BUR_actual  \
# count          650.000000     650.000000            650.000000     650.000000
# mean         10129.383077   15475.250769           7675.244615   26914.852308
# std          13268.548563   19282.513535           9788.877777   35327.607712
# min            444.000000     438.000000            363.000000     680.000000
# ...

# %%
df['Unnamed: 0.1'].value_counts()
# Out:
# Unnamed: 0.1
# 649    1
# 0      1
# 1      1
# 2      1
# 3      1
#       ..
# 14     1
# 13     1
# 12     1
# 11     1
# 10     1
# Name: count, Length: 650, dtype: int64

# %%
plt.hist(df['Unnamed: 0.1'], bins=300)
plt.show()
